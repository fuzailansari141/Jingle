# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('NewYearEvents.csv')

# %%
df
# Out:
#                                         Name_of_event  \
# 0   The Lalit Mumbai - Grand New Year Festival 202...
# 1   BIGGEST NEW YEAR BASH 2023 @ CIDCO Exhibition ...
# 2   Novotel Juhu - New Year's Eve Bollywood Bash |...
# 3   #High2Happiness: New Year Brunch Blast @ Gloca...
# 4                New Year Bash at Imagicaa | NYE 2023
# ..                                                ...
# 72                         NEW YEAR EVE @ SOHO-DELHI
# 73                New Year's Eve - Ministry Of Sound
# 74  SOLACITY : LET THE NEW YOU OUT :  31st Dec' 2022
# 75  Disco'22 - New Year's Eve @ Imperfecto Hauz Kh...
# 76   NEW YEAR CELEBRATION AT REGENTA SUITES GURUGRAM
#
#                                  Time and Date  \
# 0          December 31 | 9PM - January 1 | 3AM
# 1          December 31 | 8PM - January 1 | 1AM
# 2          December 31 | 9PM - January 1 | 3AM
# 3   December 31 | 11:30AM - January 1 | 3:30PM
# 4        December 31 | 10AM - January 1 | 12AM
# ...

# %%
df['Name_of_event']
# Out:
# 0     The Lalit Mumbai - Grand New Year Festival 202...
# 1     BIGGEST NEW YEAR BASH 2023 @ CIDCO Exhibition ...
# 2     Novotel Juhu - New Year's Eve Bollywood Bash |...
# 3     #High2Happiness: New Year Brunch Blast @ Gloca...
# 4                  New Year Bash at Imagicaa | NYE 2023
#                             ...
# 72                           NEW YEAR EVE @ SOHO-DELHI
# 73                  New Year's Eve - Ministry Of Sound
# 74    SOLACITY : LET THE NEW YOU OUT :  31st Dec' 2022
# 75    Disco'22 - New Year's Eve @ Imperfecto Hauz Kh...
# 76     NEW YEAR CELEBRATION AT REGENTA SUITES GURUGRAM
# Name: Name_of_event, Length: 77, dtype: object

# %%
df['Name_of_event']
# Out:
# 0     The Lalit Mumbai - Grand New Year Festival 202...
# 1     BIGGEST NEW YEAR BASH 2023 @ CIDCO Exhibition ...
# 2     Novotel Juhu - New Year's Eve Bollywood Bash |...
# 3     #High2Happiness: New Year Brunch Blast @ Gloca...
# 4                  New Year Bash at Imagicaa | NYE 2023
#                             ...
# 72                           NEW YEAR EVE @ SOHO-DELHI
# 73                  New Year's Eve - Ministry Of Sound
# 74    SOLACITY : LET THE NEW YOU OUT :  31st Dec' 2022
# 75    Disco'22 - New Year's Eve @ Imperfecto Hauz Kh...
# 76     NEW YEAR CELEBRATION AT REGENTA SUITES GURUGRAM
# Name: Name_of_event, Length: 77, dtype: object

# %%
def namefunc(x):
    for i in x:
        j=i.split('|')
        k=j[0]
        return k

# %%
#df['Name_of_event']=df['Name_of_event'].apply(namefunc)

# %%
df
# Out:
#                                         Name_of_event  \
# 0   The Lalit Mumbai - Grand New Year Festival 202...
# 1   BIGGEST NEW YEAR BASH 2023 @ CIDCO Exhibition ...
# 2   Novotel Juhu - New Year's Eve Bollywood Bash |...
# 3   #High2Happiness: New Year Brunch Blast @ Gloca...
# 4                New Year Bash at Imagicaa | NYE 2023
# ..                                                ...
# 72                         NEW YEAR EVE @ SOHO-DELHI
# 73                New Year's Eve - Ministry Of Sound
# 74  SOLACITY : LET THE NEW YOU OUT :  31st Dec' 2022
# 75  Disco'22 - New Year's Eve @ Imperfecto Hauz Kh...
# 76   NEW YEAR CELEBRATION AT REGENTA SUITES GURUGRAM
#
#                                  Time and Date  \
# 0          December 31 | 9PM - January 1 | 3AM
# 1          December 31 | 8PM - January 1 | 1AM
# 2          December 31 | 9PM - January 1 | 3AM
# 3   December 31 | 11:30AM - January 1 | 3:30PM
# 4        December 31 | 10AM - January 1 | 12AM
# ...

# %%
for i in df['Time and Date']:
    i=i.replace('-','to')
    i=i.replace('|','')
    print(i)
# Out:
# December 31  9PM to January 1  3AM
# December 31  8PM to January 1  1AM
# December 31  9PM to January 1  3AM
# December 31  11:30AM to January 1  3:30PM
# December 31  10AM to January 1  12AM
# December 31  8PM to January 1  3AM
# December 31  9PM to January 1  3AM
# December 31  9PM to January 1  3AM
# December 31  8:30PM to January 1  2:00AM
# December 31  3PM to January 1  11AM
# December 31  3PM to January 1  11AM
# December 31  6:05PM to January 1  12:00AM
# December 31  6PM to January 1  2AM
# December 31  7PM to January 1  5AM
# December 31  8PM to January 1  1AM
# December 31  7PM
# December 31  8PM Onwards
# December 31  7PM to January 1  1AM
# December 31  8PM to January 1  1AM
# December 31  7PM to January 1  12AM
# December 31  7PM to January 1  12AM
# December 31  7PM to January 1  1AM
# December 31  8PM to January 1  1AM
# December 31  8PM to January 1  12AM
# December 31  8PM to January 1  12AM
# December 31  6PM to January 1  1AM
# December 31  8PM to January 1  1AM
# ...

# %%
for i in df['Location']:
    i=i.split(' ',1)
    print(i)
# Out:
# ['The', 'Lalit Mumbai, Mumbai']
# ['CIDCO', 'Exhibition & Convention Centre, Navi Mumbai']
# ['Novotel', 'Mumbai Juhu Beach, Mumbai']
# ['Glocal', 'Junction, Mumbai']
# ['Imagica', 'Theme Park, Khopoli, Lonavala']
# ['Kitty', 'Su Mumbai, Mumbai']
# ['Tap', 'Resto Bar New Link Road Andheri West']
# ['The', 'Forest Club Resort, Karjat']
# ['Mahalakshmi', 'Race Course, Mumbai']
# ['Pawna', 'Lake Camping Pawnacamp, Lonavala']
# ['Revdanda', 'Fort, Alibaug']
# ['Karnala', 'Bird Sanctuary, Navi Mumbai']
# ['Sea', 'Lounge The Beach Cafe, Thane']
# ['Kalyan-Murbad', 'Road, Thane']
# ['Mayfield', 'Estate, Pune']
# ['Penthouze', 'Nightlife, Pune']
# ['The', 'Cult - Terra | House, Pune']
# ['Yolo', 'Gastro Lounge, Pune']
# ['The', 'Forest Club Resort, Karjat']
# ['Drama', '9, Pune']
# ['Prism', 'Club & Kitchen, Hyderabad']
# ['Rancho', 'De Caballos, Hyderabad']
# ['Meridian', 'Cricket Ground, Hyderabad']
# ['Taj', 'Deccan, Hyderabad']
# ['Novotel', 'Hyderabad Airport, Hyderabad']
# ...
